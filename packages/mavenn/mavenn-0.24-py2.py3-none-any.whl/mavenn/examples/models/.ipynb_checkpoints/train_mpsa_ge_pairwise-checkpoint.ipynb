# %%
# Standard imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# Insert path to mavenn beginning of path
import os
import sys
abs_path_to_mavenn = os.path.abspath('../../../')
sys.path.insert(0, abs_path_to_mavenn)

# Load mavenn
import mavenn
print(mavenn.__path__)
# Out:
# ['/Users/tareen/Desktop/Research_Projects/2020_mavenn_github/mavenn/mavenn']

# %%
# Load example data
data_df = mavenn.load_example_dataset('mpsa')
data_df.head(20)
# Out:
#     training_set  tot_ct  ex_ct         y          x
# 0           True    1588     66 -4.568430  ACGGUCCAU
# 1           True    1533    118 -3.683342  AUUGCCAGG
# 2           True    1459    399 -1.868565  ACAGCGGUA
# 3           True    1414    246 -2.516214  AACGCCAGG
# 4           True    1412     60 -4.535831  ACGGCUUGG
# 5           True    1412  11147  2.979870  AAGGUGGGA
# 6           True    1396     57 -4.582775  ACGGCUUAU
# 7          False    1384  14692  3.406907  CAGGUGGGA
# 8          False    1378  12990  3.236208  AAGGUUGGU
# 9           True    1336     43 -4.913873  UCAGUGGGA
# 10          True    1296     60 -4.419505  ACAGCGGGA
# 11          True    1296     38 -5.064857  AACGCUAGG
# 12          True    1289     53 -4.570318  AGCGCCCAU
# 13         False    1273     53 -4.560513  ACAGCACUA
# 14          True    1269     85 -3.884432  AAGGCCAGG
# 15          True    1229     75 -4.019576  CAGGCAUAU
# 16          True    1224     70 -4.113990  CACGCCCUA
# 17         False    1223  15423  3.655218  ACGGUGAGA
# 18          True    1218  12509  3.359428  CAGGUGAGA
# 19         False    1210     39 -4.919809  ACUGCAUAU

# %%
import seaborn as sns
sns.histplot(data_df['y'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-0343f899fa57> in <module>
#       1 import seaborn as sns
# ----> 2 sns.histplot(data_df['y'])
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
# Split into trianing and test data
ix = data_df['training_set']
L = len(data_df['x'][0])
train_df = data_df[ix]
print(f'training N: {len(train_df):,}')
test_df = data_df[~ix]
print(f'testing N: {len(test_df):,}')
# Out:
# training N: 24,411
# testing N: 6,079

# %%
# Set seeed
mavenn.set_seed(0)

# Define model
model = mavenn.Model(regression_type='GE',
                     L=L,
                     alphabet='rna',
                     gpmap_type='pairwise',                     
                     ge_noise_model_type='SkewedT',
                     ge_heteroskedasticity_order=2)

# %%
# Set training data
model.set_data(x=train_df['x'],
               y=train_df['y'],
               shuffle=True)
# Out:
# N = 24,411 observations set as training data.
# Data shuffled.
# Time to set data: 0.364 sec.

# %%
# Fit model to data
history = model.fit(learning_rate=.005,
                    epochs=1000,
                    batch_size=200,
                    early_stopping=True,
                    early_stopping_patience=30,
                    linear_initialization=False)
# Out:
# Epoch 1/1000
# 98/98 [==============================] - 1s 6ms/step - loss: 275.8075 - I_like: -0.5417 - val_loss: 260.8800 - val_I_like: -0.4528
# Epoch 2/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 255.5599 - I_like: -0.4000 - val_loss: 250.9135 - val_I_like: -0.3831
# Epoch 3/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 246.0195 - I_like: -0.3319 - val_loss: 241.5540 - val_I_like: -0.3176
# Epoch 4/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 236.6236 - I_like: -0.2668 - val_loss: 231.8390 - val_I_like: -0.2494
# Epoch 5/1000
# 98/98 [==============================] - 0s 2ms/step - loss: 226.8205 - I_like: -0.1971 - val_loss: 221.7394 - val_I_like: -0.1781
# Epoch 6/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 217.7998 - I_like: -0.1349 - val_loss: 213.7673 - val_I_like: -0.1220
# Epoch 7/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 210.3482 - I_like: -0.0825 - val_loss: 206.9577 - val_I_like: -0.0740
# Epoch 8/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 203.7729 - I_like: -0.0367 - val_loss: 201.0610 - val_I_like: -0.0325
# Epoch 9/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 197.9134 - I_like: 0.0048 - val_loss: 195.4904 - val_I_like: 0.0064
# Epoch 10/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 192.6057 - I_like: 0.0410 - val_loss: 190.7890 - val_I_like: 0.0399
# Epoch 11/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 187.9702 - I_like: 0.0744 - val_loss: 186.5605 - val_I_like: 0.0697
# Epoch 12/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 183.8313 - I_like: 0.1034 - val_loss: 182.7227 - val_I_like: 0.0970
# Epoch 13/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 180.3418 - I_like: 0.1286 - val_loss: 179.8997 - val_I_like: 0.1170
# Epoch 14/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 177.3749 - I_like: 0.1487 - val_loss: 176.8133 - val_I_like: 0.1392
# Epoch 15/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 174.7363 - I_like: 0.1687 - val_loss: 174.5301 - val_I_like: 0.1561
# Epoch 16/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 172.5622 - I_like: 0.1835 - val_loss: 172.5822 - val_I_like: 0.1699
# Epoch 17/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 170.8509 - I_like: 0.1947 - val_loss: 170.8970 - val_I_like: 0.1818
# Epoch 18/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 169.3926 - I_like: 0.2042 - val_loss: 169.7906 - val_I_like: 0.1892
# Epoch 19/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 168.3364 - I_like: 0.2125 - val_loss: 168.6642 - val_I_like: 0.1977
# Epoch 20/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 167.5524 - I_like: 0.2179 - val_loss: 168.2558 - val_I_like: 0.2009
# Epoch 21/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 166.6402 - I_like: 0.2240 - val_loss: 167.4020 - val_I_like: 0.2066
# Epoch 22/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 166.1379 - I_like: 0.2279 - val_loss: 166.8236 - val_I_like: 0.2106
# Epoch 23/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 165.6638 - I_like: 0.2306 - val_loss: 166.5294 - val_I_like: 0.2121
# Epoch 24/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 165.3437 - I_like: 0.2346 - val_loss: 166.2413 - val_I_like: 0.2139
# Epoch 25/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 165.0030 - I_like: 0.2362 - val_loss: 165.8550 - val_I_like: 0.2169
# Epoch 26/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 164.7662 - I_like: 0.2370 - val_loss: 165.8499 - val_I_like: 0.2171
# Epoch 27/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 164.5106 - I_like: 0.2400 - val_loss: 165.4911 - val_I_like: 0.2192
# Epoch 28/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 164.2524 - I_like: 0.2413 - val_loss: 165.2126 - val_I_like: 0.2215
# Epoch 29/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 164.0929 - I_like: 0.2424 - val_loss: 165.0565 - val_I_like: 0.2226
# Epoch 30/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 163.8769 - I_like: 0.2438 - val_loss: 165.2756 - val_I_like: 0.2213
# Epoch 31/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 163.6873 - I_like: 0.2439 - val_loss: 164.8000 - val_I_like: 0.2244
# Epoch 32/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 163.5705 - I_like: 0.2453 - val_loss: 164.6387 - val_I_like: 0.2253
# Epoch 33/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 163.4551 - I_like: 0.2467 - val_loss: 164.6580 - val_I_like: 0.2256
# Epoch 34/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 163.3523 - I_like: 0.2476 - val_loss: 164.4247 - val_I_like: 0.2269
# Epoch 35/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 163.2200 - I_like: 0.2480 - val_loss: 164.6561 - val_I_like: 0.2259
# Epoch 36/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 162.9928 - I_like: 0.2487 - val_loss: 164.2155 - val_I_like: 0.2287
# Epoch 37/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 162.9808 - I_like: 0.2503 - val_loss: 164.1546 - val_I_like: 0.2287
# Epoch 38/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 162.7307 - I_like: 0.2511 - val_loss: 164.1994 - val_I_like: 0.2290
# Epoch 39/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 162.6188 - I_like: 0.2518 - val_loss: 163.7787 - val_I_like: 0.2318
# Epoch 40/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 162.5816 - I_like: 0.2535 - val_loss: 163.9460 - val_I_like: 0.2310
# Epoch 41/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 162.4716 - I_like: 0.2539 - val_loss: 163.5909 - val_I_like: 0.2333
# Epoch 42/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 162.3481 - I_like: 0.2544 - val_loss: 163.5001 - val_I_like: 0.2340
# Epoch 43/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 162.1950 - I_like: 0.2555 - val_loss: 163.5690 - val_I_like: 0.2340
# Epoch 44/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 162.0736 - I_like: 0.2568 - val_loss: 163.4128 - val_I_like: 0.2347
# Epoch 45/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.9561 - I_like: 0.2566 - val_loss: 163.1828 - val_I_like: 0.2368
# Epoch 46/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.8695 - I_like: 0.2572 - val_loss: 163.1549 - val_I_like: 0.2366
# Epoch 47/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.7425 - I_like: 0.2583 - val_loss: 162.9987 - val_I_like: 0.2382
# Epoch 48/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.6643 - I_like: 0.2595 - val_loss: 163.0778 - val_I_like: 0.2372
# Epoch 49/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.5893 - I_like: 0.2611 - val_loss: 162.8155 - val_I_like: 0.2397
# Epoch 50/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.4555 - I_like: 0.2613 - val_loss: 163.2133 - val_I_like: 0.2360
# Epoch 51/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.3729 - I_like: 0.2611 - val_loss: 162.6490 - val_I_like: 0.2408
# Epoch 52/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.2296 - I_like: 0.2629 - val_loss: 162.6487 - val_I_like: 0.2416
# Epoch 53/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.0530 - I_like: 0.2641 - val_loss: 162.3894 - val_I_like: 0.2435
# Epoch 54/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 161.0718 - I_like: 0.2654 - val_loss: 162.2633 - val_I_like: 0.2442
# Epoch 55/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 160.9109 - I_like: 0.2658 - val_loss: 162.1423 - val_I_like: 0.2455
# Epoch 56/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 160.8557 - I_like: 0.2663 - val_loss: 162.1158 - val_I_like: 0.2457
# Epoch 57/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 160.7153 - I_like: 0.2678 - val_loss: 161.9686 - val_I_like: 0.2471
# Epoch 58/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 160.5659 - I_like: 0.2678 - val_loss: 161.9576 - val_I_like: 0.2475
# Epoch 59/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 160.5076 - I_like: 0.2694 - val_loss: 161.7479 - val_I_like: 0.2488
# Epoch 60/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 160.4102 - I_like: 0.2700 - val_loss: 161.6902 - val_I_like: 0.2495
# Epoch 61/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 160.1872 - I_like: 0.2705 - val_loss: 161.5978 - val_I_like: 0.2502
# Epoch 62/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 160.2950 - I_like: 0.2726 - val_loss: 161.4400 - val_I_like: 0.2516
# Epoch 63/1000
# 98/98 [==============================] - 1s 5ms/step - loss: 160.0753 - I_like: 0.2723 - val_loss: 161.4466 - val_I_like: 0.2513
# Epoch 64/1000
# 98/98 [==============================] - 0s 5ms/step - loss: 159.8821 - I_like: 0.2745 - val_loss: 161.6939 - val_I_like: 0.2506
# Epoch 65/1000
# 98/98 [==============================] - 1s 7ms/step - loss: 159.8311 - I_like: 0.2751 - val_loss: 161.2560 - val_I_like: 0.2538
# Epoch 66/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 159.6792 - I_like: 0.2753 - val_loss: 161.1305 - val_I_like: 0.2544
# Epoch 67/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 159.5570 - I_like: 0.2763 - val_loss: 160.9715 - val_I_like: 0.2560
# Epoch 68/1000
# 98/98 [==============================] - 1s 8ms/step - loss: 159.4710 - I_like: 0.2764 - val_loss: 161.1877 - val_I_like: 0.2547
# Epoch 69/1000
# 98/98 [==============================] - 0s 5ms/step - loss: 159.3348 - I_like: 0.2783 - val_loss: 160.9855 - val_I_like: 0.2564
# Epoch 70/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 159.4606 - I_like: 0.2783 - val_loss: 160.7628 - val_I_like: 0.2581
# Epoch 71/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 159.2785 - I_like: 0.2809 - val_loss: 160.6672 - val_I_like: 0.2588
# Epoch 72/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 159.1121 - I_like: 0.2816 - val_loss: 160.5326 - val_I_like: 0.2597
# Epoch 73/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 159.1961 - I_like: 0.2810 - val_loss: 160.6626 - val_I_like: 0.2594
# Epoch 74/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 158.8992 - I_like: 0.2834 - val_loss: 160.5266 - val_I_like: 0.2596
# Epoch 75/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 158.9686 - I_like: 0.2831 - val_loss: 160.3629 - val_I_like: 0.2616
# Epoch 76/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 158.7390 - I_like: 0.2846 - val_loss: 160.1953 - val_I_like: 0.2628
# Epoch 77/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 158.8087 - I_like: 0.2847 - val_loss: 160.1227 - val_I_like: 0.2637
# Epoch 78/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 158.5055 - I_like: 0.2854 - val_loss: 159.9975 - val_I_like: 0.2645
# Epoch 79/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 158.4018 - I_like: 0.2873 - val_loss: 160.1665 - val_I_like: 0.2628
# Epoch 80/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 158.2844 - I_like: 0.2888 - val_loss: 160.0313 - val_I_like: 0.2649
# Epoch 81/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 158.1376 - I_like: 0.2892 - val_loss: 159.8507 - val_I_like: 0.2663
# Epoch 82/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 158.1407 - I_like: 0.2897 - val_loss: 159.5893 - val_I_like: 0.2681
# Epoch 83/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 158.0340 - I_like: 0.2890 - val_loss: 159.5361 - val_I_like: 0.2683
# Epoch 84/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 158.0866 - I_like: 0.2907 - val_loss: 159.4677 - val_I_like: 0.2692
# Epoch 85/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 157.6588 - I_like: 0.2921 - val_loss: 159.3814 - val_I_like: 0.2700
# Epoch 86/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 157.8513 - I_like: 0.2927 - val_loss: 159.2203 - val_I_like: 0.2713
# Epoch 87/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 157.6465 - I_like: 0.2944 - val_loss: 159.4710 - val_I_like: 0.2700
# Epoch 88/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 157.3980 - I_like: 0.2958 - val_loss: 159.1062 - val_I_like: 0.2721
# Epoch 89/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 157.3687 - I_like: 0.2961 - val_loss: 158.9471 - val_I_like: 0.2737
# Epoch 90/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 157.1205 - I_like: 0.2965 - val_loss: 159.3717 - val_I_like: 0.2699
# Epoch 91/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 157.1427 - I_like: 0.2982 - val_loss: 158.7486 - val_I_like: 0.2755
# Epoch 92/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 156.7722 - I_like: 0.2999 - val_loss: 159.3773 - val_I_like: 0.2719
# Epoch 93/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 156.8840 - I_like: 0.2977 - val_loss: 158.7242 - val_I_like: 0.2764
# Epoch 94/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 156.6138 - I_like: 0.3009 - val_loss: 158.8440 - val_I_like: 0.2759
# Epoch 95/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 156.3738 - I_like: 0.3034 - val_loss: 158.2854 - val_I_like: 0.2798
# Epoch 96/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 156.0827 - I_like: 0.3046 - val_loss: 158.1482 - val_I_like: 0.2811
# Epoch 97/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 155.9616 - I_like: 0.3063 - val_loss: 158.0118 - val_I_like: 0.2822
# Epoch 98/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 155.8497 - I_like: 0.3091 - val_loss: 157.7043 - val_I_like: 0.2846
# Epoch 99/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 155.5054 - I_like: 0.3105 - val_loss: 157.4857 - val_I_like: 0.2861
# Epoch 100/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 155.3029 - I_like: 0.3125 - val_loss: 157.3364 - val_I_like: 0.2874
# Epoch 101/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 155.1149 - I_like: 0.3140 - val_loss: 157.2024 - val_I_like: 0.2892
# Epoch 102/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 154.5997 - I_like: 0.3173 - val_loss: 156.7886 - val_I_like: 0.2921
# Epoch 103/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 154.3830 - I_like: 0.3203 - val_loss: 156.6965 - val_I_like: 0.2937
# Epoch 104/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 153.8865 - I_like: 0.3235 - val_loss: 156.6273 - val_I_like: 0.2949
# Epoch 105/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 153.5237 - I_like: 0.3264 - val_loss: 156.2629 - val_I_like: 0.2970
# Epoch 106/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 152.5283 - I_like: 0.3332 - val_loss: 154.4564 - val_I_like: 0.3101
# Epoch 107/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 152.3584 - I_like: 0.3348 - val_loss: 158.6715 - val_I_like: 0.2797
# Epoch 108/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 154.1836 - I_like: 0.3214 - val_loss: 156.6376 - val_I_like: 0.2946
# Epoch 109/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 153.4596 - I_like: 0.3272 - val_loss: 155.9562 - val_I_like: 0.2993
# Epoch 110/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 153.0640 - I_like: 0.3311 - val_loss: 156.1451 - val_I_like: 0.2980
# Epoch 111/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 152.5189 - I_like: 0.3339 - val_loss: 155.9998 - val_I_like: 0.2999
# Epoch 112/1000
# 98/98 [==============================] - 0s 5ms/step - loss: 151.6405 - I_like: 0.3396 - val_loss: 155.8386 - val_I_like: 0.3014
# Epoch 113/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 151.9402 - I_like: 0.3371 - val_loss: 154.1802 - val_I_like: 0.3125
# Epoch 114/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 152.2899 - I_like: 0.3366 - val_loss: 156.2858 - val_I_like: 0.2984
# Epoch 115/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 150.1225 - I_like: 0.3526 - val_loss: 156.3743 - val_I_like: 0.2986
# Epoch 116/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 151.5685 - I_like: 0.3417 - val_loss: 155.5370 - val_I_like: 0.3037
# Epoch 117/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 150.3919 - I_like: 0.3498 - val_loss: 154.1680 - val_I_like: 0.3153
# Epoch 118/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 151.7392 - I_like: 0.3413 - val_loss: 156.1078 - val_I_like: 0.3030
# Epoch 119/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 151.6673 - I_like: 0.3412 - val_loss: 154.9757 - val_I_like: 0.3082
# Epoch 120/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 151.3160 - I_like: 0.3426 - val_loss: 154.6151 - val_I_like: 0.3117
# Epoch 121/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 149.7661 - I_like: 0.3562 - val_loss: 162.0415 - val_I_like: 0.2545
# Epoch 122/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 3081.7480 - I_like: -20.7165 - val_loss: 157.1589 - val_I_like: 0.2918
# Epoch 123/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 155.0750 - I_like: 0.3169 - val_loss: 154.1868 - val_I_like: 0.3131
# Epoch 124/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 153.1983 - I_like: 0.3297 - val_loss: 153.6647 - val_I_like: 0.3189
# Epoch 125/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 152.1322 - I_like: 0.3370 - val_loss: 156.9716 - val_I_like: 0.2932
# Epoch 126/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 151.2849 - I_like: 0.3434 - val_loss: 155.1846 - val_I_like: 0.3077
# Epoch 127/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 151.7558 - I_like: 0.3406 - val_loss: 157.4049 - val_I_like: 0.2901
# Epoch 128/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 149.7382 - I_like: 0.3549 - val_loss: 154.5240 - val_I_like: 0.3103
# Epoch 129/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 151.9146 - I_like: 0.3392 - val_loss: 153.1023 - val_I_like: 0.3223
# Epoch 130/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 148.4957 - I_like: 0.3647 - val_loss: 156.9372 - val_I_like: 0.2945
# Epoch 131/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 151.5297 - I_like: 0.3435 - val_loss: 158.2654 - val_I_like: 0.2848
# Epoch 132/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 148.8125 - I_like: 0.3634 - val_loss: 152.3471 - val_I_like: 0.3275
# Epoch 133/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 149.9461 - I_like: 0.3532 - val_loss: 161.8560 - val_I_like: 0.2587
# Epoch 134/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 145.8206 - I_like: 0.3842 - val_loss: 156.9537 - val_I_like: 0.2937
# Epoch 135/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 148.9505 - I_like: 0.3615 - val_loss: 161.3770 - val_I_like: 0.2637
# Epoch 136/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 151.6646 - I_like: 0.3417 - val_loss: 143.1151 - val_I_like: 0.3909
# Epoch 137/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 148.4254 - I_like: 0.3645 - val_loss: 152.0206 - val_I_like: 0.3344
# Epoch 138/1000
# 98/98 [==============================] - 0s 3ms/step - loss: 158.6242 - I_like: 0.2915 - val_loss: 164.3244 - val_I_like: 0.2432
# Epoch 139/1000
# 98/98 [==============================] - 0s 4ms/step - loss: 152.0487 - I_like: 0.3385 - val_loss: 293.3080 - val_I_like: -0.6768
# Epoch 140/1000
# 98/98 [==============================] - 0s 4ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 141/1000
# 98/98 [==============================] - 0s 4ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 142/1000
# 98/98 [==============================] - 0s 3ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 143/1000
# 98/98 [==============================] - 0s 3ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 144/1000
# 98/98 [==============================] - 0s 3ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 145/1000
# 98/98 [==============================] - 0s 3ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 146/1000
# 98/98 [==============================] - 0s 3ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 147/1000
# 98/98 [==============================] - 0s 4ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 148/1000
# 98/98 [==============================] - 0s 4ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 149/1000
# 98/98 [==============================] - 0s 4ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 150/1000
# 98/98 [==============================] - 0s 4ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 151/1000
# 98/98 [==============================] - 0s 4ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 152/1000
# 98/98 [==============================] - 0s 4ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 153/1000
# 98/98 [==============================] - 0s 4ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 154/1000
# 98/98 [==============================] - 0s 3ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 155/1000
# 98/98 [==============================] - 0s 3ms/step - loss: nan - I_like: nan - val_loss: nan - val_I_like: nan
# Epoch 156/1000
# 23/98 [======>.......................] - ETA: 0s - loss: nan - I_like: nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0fbf445a1aa0> in <module>
#       5                     early_stopping=True,
#       6                     early_stopping_patience=30,
# ----> 7                     linear_initialization=False)
#
# ~/Desktop/Research_Projects/2020_mavenn_github/mavenn/mavenn/src/error_handling.py in wrapped_func(*args, **kwargs)
#      96         try:
#      97             # Execute function
# ---> 98             result = func(*args, **kwargs)
#      99
#     100             # If running functional test and expect to fail
#
# ~/Desktop/Research_Projects/2020_mavenn_github/mavenn/mavenn/src/model.py in fit(self, epochs, learning_rate, validation_split, verbose, early_stopping, early_stopping_patience, batch_size, linear_initialization, callbacks, optimizer, optimizer_kwargs, fit_kwargs)
#     610                                        callbacks=callbacks,
#     611                                        batch_size=batch_size,
# --> 612                                        **fit_kwargs)
#     613
#     614         # Get function representing the raw gp_map
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/miniconda3/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
x = tf.constant(100.)
y = tf.constant(1.E20)
K.min([K.exp(x), y])

# %%
# Save model
model.save('mpsa_ge_pairwise')

# %%
# Load model
model = mavenn.load('mpsa_ge_pairwise')

# %%
# Get x and y
x_test = test_df['x'].values
y_test = test_df['y'].values

# %%
# Show training history
print('On test data:')

# Compute likelihood information
I_like, dI_like =  model.I_likelihood(x=x_test, y=y_test)
print(f'I_like_test: {I_like:.3f} +- {dI_like:.3f} bits') 

# Compute predictive information
I_pred, dI_pred = model.I_predictive(x=x_test, y=y_test)
print(f'I_pred_test: {I_pred:.3f} +- {dI_pred:.3f} bits')

I_like_hist = model.history['I_like']
val_I_like_hist = model.history['val_I_like']

fig, ax = plt.subplots(1,1,figsize=[4,4])
ax.plot(I_like_hist, label='I_like_train')
ax.plot(val_I_like_hist, label='I_like_val')
ax.axhline(I_like, color='C2', linestyle=':', label='I_like_test')
ax.axhline(I_pred, color='C3', linestyle=':', label='I_pred_test')
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('bits')
ax.set_title('training hisotry')
ax.set_ylim([0, I_pred*1.2]);

# %%
# Predict latent phentoype values (phi) on test data
phi_test = model.x_to_phi(x_test)

# Predict measurement values (yhat) on test data
yhat_test = model.x_to_yhat(x_test)

# Set phi lims and create grid in phi space
phi_lim = [min(phi_test)-.5, max(phi_test)+.5]
phi_grid = np.linspace(phi_lim[0], phi_lim[1], 1000)

# Compute yhat each phi gridpoint
yhat_grid = model.phi_to_yhat(phi_grid)

# Compute 90% CI for each yhat
q = [0.05, 0.95] #[0.16, 0.84]
yqs_grid = model.yhat_to_yq(yhat_grid, q=q)

# Create figure
fig, ax = plt.subplots(1, 1, figsize=[4, 4])

# Illustrate measurement process with GE curve
ax.scatter(phi_test, y_test, color='C0', s=5, alpha=.2, label='test data')
ax.plot(phi_grid, yhat_grid, linewidth=2, color='C1',
        label='$\hat{y} = g(\phi)$')
ax.plot(phi_grid, yqs_grid[:, 0], linestyle='--', color='C1', label='68% CI')
ax.plot(phi_grid, yqs_grid[:, 1], linestyle='--', color='C1')
ax.set_xlim(phi_lim)
ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_ylabel('measurement ($y$)')
ax.set_title('measurement process')
ax.legend()

# Fix up plot
fig.tight_layout()
plt.show()

# %%
# Plot pairwise parameters
theta = model.get_theta()
fig, ax = plt.subplots(1, 1, figsize=[8, 4])
mavenn.heatmap_pairwise(values=theta['theta_lclc'],
                        alphabet=theta['alphabet'],
                        ax=ax);

# %%
# Test simulate_data
sim_df = model.simulate_dataset(N=1000)
sim_df.head()
