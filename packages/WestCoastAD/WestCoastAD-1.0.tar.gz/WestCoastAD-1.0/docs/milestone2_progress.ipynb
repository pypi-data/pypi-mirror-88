# %% [markdown]
# ## Milestone 2 Task Assignments
#
# ### Anita
#
# * implement scalar value and derivative computation for the following elementary functions: `__add__`, `__radd__`, `sin`, `sinh`, `arcsin`, `tan`,
# * `__repr__` implementation and testing
# * unit test the above implementations
# * update how to use the package section of docs
#
# ### Erik
#
# * implement scalar value and derivative computation for the following elementary functions: `__mul__`, `__rmul__`, `__truediv__`, `__rtruediv__`, `arctan`, `tanh`
# * `__str__` implementation
# * unit test the above implementations
# * update software organization section of docs
#
#
# ### Heather
#
# * implement scalar value and derivative computation for the following elementary functions: `__sub__`, `__rsub__`, `__neg__`, `cos`, `cosh`, `arccos`
# * property getter and setter for `derivative` and `value` to ensure proper input type
# * unit test the above implementations
# * update future features section of docs
#
# ### Lekshmi
#
# * implement scalar value and derivative computation for the following elementary functions: `__pow__`, `__rpow__`, `log`, `exp`, `sqrt`, `abs`
# * integration testing of combinations of all the methods for scalar derivative computation
# * unit test the above implementations
# * update implementation section of docs
#
# ## Milestone 2B Progress
#
# ### Anita
# * implementation and initial testing for: `__add__`, `__radd__`, `sin`, `sinh`, `arcsin`, `tan`
#
# ### Erik
# * Completed `__mul__` and `__rmul__`
#
#
# ### Heather
# * Completed `__sub__`, `__rsub__`, `__neg__`
#
# ### Lekshmi
# * Implementation and unit tests for `exp` and `log`
