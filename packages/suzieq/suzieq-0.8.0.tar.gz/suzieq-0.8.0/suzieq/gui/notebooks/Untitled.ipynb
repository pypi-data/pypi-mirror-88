# %%
from suzieq.sqobjects.bgp import BgpObj
import ipywidgets as widgets

# %%
df = BgpObj().get()

# %%
df
# Out:
#     namespace hostname      vrf        peer peerHostname        state    asn  \
# 0         eos   edge01  default      eth1.2                   NotEstd  65530
# 1         eos   edge01  default      eth1.4                   NotEstd  65530
# 2         eos   edge01  default      eth2.2                   NotEstd  65530
# 3         eos   edge01  default      eth2.4                   NotEstd  65530
# 4         eos   exit01  default  10.127.0.8               Established  65201
# ..        ...      ...      ...         ...          ...          ...    ...
# 82  ibgp-evpn  spine02  default        swp1       leaf01  Established  65000
# 87  ibgp-evpn  spine02  default        swp2       leaf02  Established  65000
# 90  ibgp-evpn  spine02  default        swp3       leaf03  Established  65000
# 93  ibgp-evpn  spine02  default        swp4       leaf04  Established  65000
# 96  ibgp-evpn  spine02  default        swp6       exit01  Established  65000
#
# ...
